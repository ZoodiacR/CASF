# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoodiacR/CASF/blob/main/3_3_2_THEORY_SQL_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Databases
#
# ## Introduction
#
# A huge amount of data lives in databases, so it's essential that you know how to access them. Sometimes you can ask someone to download a snapshot into a .csv for you, but this gets painful quickly: every time you need to make a change you'll have to communicate with another human. You want to be able to reach into the database directly to get the data you need, when you need it.
#
# In this chapter, you'll first learn the basics of Python packages that can interact with SQL databases.
#
# ## Connecting to Databases
#
# To connect to a database from Python, there are a number of options, but it does depend on what *kind* of database you are connecting to. The steps (eg connect to the database, upload data, run SQL series) are similar though, so we won't lose much by just choosing one example.
#
# SQLite is a small, fast, self-contained, SQL database engine and the most used database engine in the world. A lot of the data on your computer and mobile phone will in fact be in SQLite databases.
#
# We will always need two steps though, regardless of what kind of SQL database we are connecting to:
#
# - You'll always use a database interface that provides a connection to the database, for example Python's built-in **sqlite** package.
# - You'll also use a package that pushes and/or pulls data to/from the database, for example **pandas**.

# %% [markdown]
# ## Working with Databases Directly
#
# Let's connect to a small SQLite database called the [Chinook database](https://github.com/lerocha/chinook-database), which contains information about the artists, songs, and albums from a music shop, as well as information on the shop's employees, customers, and the customers purchases. This information is contained in eleven tables. The figure below shows the data schema:
#
# For starters, let's use Python's built in **sqlite3** engine to connect to the database and execute a very simple SQL query to select the first ten entries from the 'Artists' table:

# %%
import sqlite3

import pandas as pd

# %%
# We need to first download the .sqlite database file
# !gdown "1Pedy3vxwYWFOJjADGYBRN2IA95glpIfF"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Pedy3vxwYWFOJjADGYBRN2IA95glpIfF
# To: /content/Chinook_Sqlite.sqlite
# 100% 1.07M/1.07M [00:00<00:00, 8.01MB/s]

# %%
# We can establish a connection to the database with this command
con = sqlite3.connect("Chinook_Sqlite.sqlite")

# %%
# List all the tables
# First we must type the SQL command and execute it with execute()
# In SQLite, sqlite_master is a special system table that stores metadata about
# the database schema. It contains information about all the tables, indexes,
# views, and triggers in the database.

cursor = con.execute(
  """
  SELECT name
  FROM sqlite_master
  WHERE type='table';
  """
)

# Then we can retreive the results using fetchall()
rows = cursor.fetchall()
rows
# Out:
# [('Album',),
#  ('Artist',),
#  ('Customer',),
#  ('Employee',),
#  ('Genre',),
#  ('Invoice',),
#  ('InvoiceLine',),
#  ('MediaType',),
#  ('Playlist',),
#  ('PlaylistTrack',),
#  ('Track',)]

# %%
# Let's see another example
# Listing only 50 artists
cursor = con.execute(
  """
  SELECT *
  FROM Artist
  ORDER BY Name ASC
  LIMIT 5;
  """
)

rows = cursor.fetchall()
rows
# Out:
# [(43, 'A Cor Do Som'),
#  (1, 'AC/DC'),
#  (230, 'Aaron Copland & London Symphony Orchestra'),
#  (202, 'Aaron Goldberg'),
#  (214, 'Academy of St. Martin in the Fields & Sir Neville Marriner')]

# %%
type(rows[0])
# Out:
# tuple

# %% [markdown]
# Note that the output here is in the form a Python object called a tuple. If we wanted to put this into a **pandas** dataframe, we can just pass it straight in:

# %%
import pandas as pd

pd.DataFrame(rows)
# Out:
#      0                                                  1
# 0   43                                       A Cor Do Som
# 1    1                                              AC/DC
# 2  230          Aaron Copland & London Symphony Orchestra
# 3  202                                     Aaron Goldberg
# 4  214  Academy of St. Martin in the Fields & Sir Nevi...

# %% [markdown]
# Another useful hint is that if you're not sure what the column names are, you can obtain them from:

# %%
[i[0] for i in cursor.description]
# Out:
# ['ArtistId', 'Name']

# %% [markdown]
# Putting all togheter...

# %%
df = pd.DataFrame(rows, columns=[i[0] for i in cursor.description])
df.head()
# Out:
#    ArtistId                                               Name
# 0        43                                       A Cor Do Som
# 1         1                                              AC/DC
# 2       230          Aaron Copland & London Symphony Orchestra
# 3       202                                     Aaron Goldberg
# 4       214  Academy of St. Martin in the Fields & Sir Nevi...

# %%
df.set_index("ArtistId").head()
# Out:
#                                                        Name
# ArtistId
# 43                                             A Cor Do Som
# 1                                                     AC/DC
# 230               Aaron Copland & London Symphony Orchestra
# 202                                          Aaron Goldberg
# 214       Academy of St. Martin in the Fields & Sir Nevi...

# %% [markdown]
# ### Creating a Database
#
# Often, you'll want to create a SQL database to later (efficiently) access cuts of data. Let's create a test database directly using the **sqlite** package. This process involves a `CREATE TABLE` statement, then the name of the table followed by the names of the columns and their data types.

# %%
create_query = """CREATE TABLE test (country VARCHAR(20), gdp REAL, health INTEGER);"""
con_new = sqlite3.connect("test3_database.sqlite")
con_new.execute(create_query)
con_new.commit()

# %% [markdown]
# If this runs, then you've created a test database! (You can check the data directory on your own computer to see if it worked, but you'll get an error if the data directory doesn't already exist.)
#
# Let's now fill the database with some values:

# %%
test_data = [("MX", 1, 3), ("Col", 0.6, 2), ("Argentina", 0.8, 1)]

con_new.executemany("INSERT INTO test VALUES(?, ?, ?)", test_data)
con_new.commit()

# %% [markdown]
# Finally, let's check if this has worked:

# %%
con_new.execute("SELECT * FROM test").fetchall()
# Out:
# [('MX', 1.0, 3),
#  ('Col', 0.6, 2),
#  ('Argentina', 0.8, 1),
#  ('MX', 1.0, 3),
#  ('Col', 0.6, 2),
#  ('Argentina', 0.8, 1)]

# %% [markdown]
# ## SQL with **pandas**
#
# **Pandas** is well-equipped for working with SQL. We can simply push the query we just created straight through using its `read_sql` function—but bear in mind we need to pass in the connection we created to the database too:

# %%
con = sqlite3.connect("Chinook_Sqlite.sqlite")

# %%
sql_top10_artists = """
  SELECT *
  FROM Artist
  LIMIT 10;
"""

df_top10_artists = pd.read_sql(sql_top10_artists, con)
df_top10_artists
# Out:
#    ArtistId                  Name
# 0         1                 AC/DC
# 1         2                Accept
# 2         3             Aerosmith
# 3         4     Alanis Morissette
# 4         5       Alice In Chains
# 5         6  Antônio Carlos Jobim
# 6         7          Apocalyptica
# 7         8            Audioslave
# 8         9              BackBeat
# 9        10          Billy Cobham

# %% [markdown]
# One nice feature of this is that the column names in SQL get passed straight to the column names in our dataframe.

# %% [markdown]
# ### Creating a SQL Table from Pandas Dataframe
#
# Now I will use the table above to show how you can also create your own tables in the SQLite Database using pandas:

# %%
type(df_top10_artists)
# Out:
# pandas.core.frame.DataFrame

# %%
df_top10_artists.to_sql('Top10_Artist', con)
# Out:
# 10

# %%
# List all the tables, Top10_Artist should be included now
sql_list_tables = """
  SELECT name
  FROM sqlite_master
  WHERE type='table';
  """

pd.read_sql(sql_list_tables, con)
# Out:
#              name
# 0           Album
# 1          Artist
# 2        Customer
# 3        Employee
# 4           Genre
# 5         Invoice
# 6     InvoiceLine
# 7       MediaType
# 8        Playlist
# 9   PlaylistTrack
# 10          Track

# %% [markdown]
# ### Examples of SQL queries with Pandas

# %%
sql_query = """
-- SELECT example: Select InvoiceId, BillingAddress and BillingCity columns from Invoice table. (This is a comment and won’t be executed)
SELECT InvoiceId, BillingAddress, BillingCity
FROM Invoice;
"""

pd.read_sql(sql_query, con)
# Out:
#      InvoiceId                            BillingAddress BillingCity
# 0            1                   Theodor-Heuss-Straße 34   Stuttgart
# 1            2                          Ullevålsveien 14        Oslo
# 2            3                           Grétrystraat 63    Brussels
# 3            4                            8210 111 ST NW    Edmonton
# 4            5                           69 Salem Street      Boston
# ..         ...                                       ...         ...
# 407        408                     319 N. Frances Street     Madison
# 408        409                    796 Dundas Street West     Toronto
# 409        410  Rua dos Campeões Europeus de Viena, 4350       Porto
# 410        411                           Porthaninkatu 9    Helsinki
# 411        412                       12,Community Centre       Delhi
#
# [412 rows x 3 columns]

# %%
sql_query = """
-- WHERE example: Select all the invoices billed from Argentina in which the spent value is over $5
SELECT *
FROM Invoice
WHERE Invoice.BillingCountry = 'Argentina' AND Invoice.Total BETWEEN 5 AND 10;
"""

pd.read_sql(sql_query, con)
# Out:
#    InvoiceId  CustomerId          InvoiceDate      BillingAddress  \
# 0        164          56  2010-12-17 00:00:00  307 Macacha Güemes
# 1        403          56  2013-11-08 00:00:00  307 Macacha Güemes
#
#     BillingCity BillingState BillingCountry BillingPostalCode  Total
# 0  Buenos Aires         None      Argentina              1106   5.94
# 1  Buenos Aires         None      Argentina              1106   8.91

# %%
sql_query = """
-- More complex example with alias
SELECT DISTINCT c.FirstName FROM Customer as c;

"""


pd.read_sql(sql_query, con)
# Out:
#     FirstName
# 0        Luís
# 1      Leonie
# 2    François
# 3       Bjørn
# 4   František
# 5      Helena
# 6      Astrid
# 7        Daan
# 8        Kara
# 9     Eduardo
# 10  Alexandre
# 11    Roberto
# 12   Fernanda
# 13       Mark
# 14   Jennifer
# 15      Frank
# 16       Jack
# 17   Michelle
# 18        Tim
# 19        Dan
# 20      Kathy
# 21    Heather
# 22       John
# 23     Victor
# 24    Richard
# 25    Patrick
# 26      Julia
# 27     Robert
# 28     Edward
# 29     Martha
# 30      Aaron
# 31      Ellie
# 32       João
# 33   Madalena
# 34     Hannah
# 35       Fynn
# 36     Niklas
# 37    Camille
# 38  Dominique
# 39       Marc
# 40      Wyatt
# 41   Isabelle
# 42      Terhi
# 43   Ladislav
# 44       Hugh
# 45      Lucas
# 46   Johannes
# 47  Stanisław
# 48    Enrique
# 49     Joakim
# 50       Emma
# 51       Phil
# 52      Steve
# 53      Diego
# 54       Luis
# 55      Manoj
# 56       Puja

# %%
sql_query = """
-- More complex example with alias
SELECT *
FROM Customer as c, Invoice AS i
WHERE (c.FirstName IN (SELECT DISTINCT c.FirstName FROM Customer as c) ) AND c.CustomerId = i.CustomerId
ORDER BY c.FirstName, c.LastName DESC;
"""

pd.read_sql(sql_query, con)
# Out:
#      CustomerId FirstName  LastName Company                 Address      City  \
# 0            32     Aaron  Mitchell    None      696 Osborne Street  Winnipeg
# 1            32     Aaron  Mitchell    None      696 Osborne Street  Winnipeg
# 2            32     Aaron  Mitchell    None      696 Osborne Street  Winnipeg
# 3            32     Aaron  Mitchell    None      696 Osborne Street  Winnipeg
# 4            32     Aaron  Mitchell    None      696 Osborne Street  Winnipeg
# ..          ...       ...       ...     ...                     ...       ...
# 407          42     Wyatt    Girard    None  9, Place Louis Barthou  Bordeaux
# 408          42     Wyatt    Girard    None  9, Place Louis Barthou  Bordeaux
# 409          42     Wyatt    Girard    None  9, Place Louis Barthou  Bordeaux
# 410          42     Wyatt    Girard    None  9, Place Louis Barthou  Bordeaux
# 411          42     Wyatt    Girard    None  9, Place Louis Barthou  Bordeaux
#
#     State Country PostalCode               Phone  ... SupportRepId InvoiceId  \
# 0      MB  Canada    R3L 2B9   +1 (204) 452-6452  ...            4        50
# 1      MB  Canada    R3L 2B9   +1 (204) 452-6452  ...            4        61
# 2      MB  Canada    R3L 2B9   +1 (204) 452-6452  ...            4       116
# 3      MB  Canada    R3L 2B9   +1 (204) 452-6452  ...            4       245
# 4      MB  Canada    R3L 2B9   +1 (204) 452-6452  ...            4       268
# ..    ...     ...        ...                 ...  ...          ...       ...
# 407  None  France      33000  +33 05 56 96 96 96  ...            3        83
# 408  None  France      33000  +33 05 56 96 96 96  ...            3       204
# 409  None  France      33000  +33 05 56 96 96 96  ...            3       215
# 410  None  France      33000  +33 05 56 96 96 96  ...            3       270
# 411  None  France      33000  +33 05 56 96 96 96  ...            3       399
#
#      CustomerId          InvoiceDate          BillingAddress BillingCity  \
# 0            32  2009-08-06 00:00:00      696 Osborne Street    Winnipeg
# 1            32  2009-09-16 00:00:00      696 Osborne Street    Winnipeg
# 2            32  2010-05-17 00:00:00      696 Osborne Street    Winnipeg
# 3            32  2011-12-22 00:00:00      696 Osborne Street    Winnipeg
# 4            32  2012-03-25 00:00:00      696 Osborne Street    Winnipeg
# ..          ...                  ...                     ...         ...
# 407          42  2009-12-26 00:00:00  9, Place Louis Barthou    Bordeaux
# 408          42  2011-06-19 00:00:00  9, Place Louis Barthou    Bordeaux
# 409          42  2011-07-30 00:00:00  9, Place Louis Barthou    Bordeaux
# 410          42  2012-03-29 00:00:00  9, Place Louis Barthou    Bordeaux
# 411          42  2013-11-03 00:00:00  9, Place Louis Barthou    Bordeaux
#
#     BillingState BillingCountry BillingPostalCode  Total
# 0             MB         Canada           R3L 2B9   1.98
# 1             MB         Canada           R3L 2B9  13.86
# 2             MB         Canada           R3L 2B9   8.91
# 3             MB         Canada           R3L 2B9   1.98
# 4             MB         Canada           R3L 2B9   3.96
# ..           ...            ...               ...    ...
# 407         None         France             33000   0.99
# 408         None         France             33000   3.98
# 409         None         France             33000  13.86
# 410         None         France             33000   8.91
# 411         None         France             33000   1.98
#
# [412 rows x 22 columns]

# %%
sql_query = """
-- GROUP BY example: Number of sales and average amount spent by Country during 2010
SELECT COUNT(*) as Sales_by_Country, AVG(i.Total) as Average_spent, i.BillingCountry as Country
FROM Invoice AS i
WHERE i.InvoiceDate BETWEEN '2010-01-01 00:00:00' and '2010-31-12 00:00:00'
GROUP BY i.BillingCountry
ORDER BY Sales_by_Country DESC;
"""

pd.read_sql(sql_query, con)
# Out:
#     Sales_by_Country  Average_spent         Country
# 0                 18       5.721111             USA
# 1                 12       6.355000          Canada
# 2                  8       4.950000          France
# 3                  8       5.200000          Brazil
# 4                  5       6.138000  United Kingdom
# 5                  4       6.435000         Germany
# 6                  3       2.310000        Portugal
# 7                  3       3.630000           Italy
# 8                  3       5.943333           India
# 9                  3      10.916667         Hungary
# 10                 3       3.960000       Argentina
# 11                 2       3.965000          Sweden
# 12                 2       3.465000         Denmark
# 13                 2       4.950000  Czech Republic
# 14                 2      13.885000         Austria
# 15                 1       1.980000           Spain
# 16                 1       8.910000          Poland
# 17                 1       1.980000     Netherlands
# 18                 1      17.910000           Chile
# 19                 1       0.990000       Australia

# %%
sql_query = """
-- GROUP BY example: Number of sales and average amount spent by Country, only for those who had more than 10 sales
SELECT COUNT(*) as Sales_by_Country, AVG(i.Total) as Average_spent, i.BillingCountry as Country
FROM Invoice AS i
GROUP BY i.BillingCountry
HAVING Sales_by_Country > 10
ORDER BY Sales_by_Country DESC;
"""

pd.read_sql(sql_query, con)
# Out:
#    Sales_by_Country  Average_spent         Country
# 0                91       5.747912             USA
# 1                56       5.427857          Canada
# 2                35       5.574286          France
# 3                35       5.431429          Brazil
# 4                28       5.588571         Germany
# 5                21       5.374286  United Kingdom
# 6                14       5.517143        Portugal
# 7                14       6.445714  Czech Republic
# 8                13       5.789231           India

# %%
sql_query = """
-- CASE + GRUOP BY example: Count Tracks by Quality
SELECT case_result.AudioQuality, COUNT(*) FROM (
    SELECT *,
    (CASE
    	WHEN Track.Bytes < 2000000 THEN 'Poor-Quality'
        WHEN Track.Bytes >= 2000000 AND Track.Bytes <= 8000000 THEN 'Mid-Quality'
        WHEN Track.Bytes > 8000000 THEN 'High-Quality'
    END) AS AudioQuality
    FROM Track
    ORDER BY Track.Bytes ASC
) AS case_result
GROUP BY case_result.AudioQuality;
"""

pd.read_sql(sql_query, con)
# Out:
#    AudioQuality  COUNT(*)
# 0  High-Quality      1814
# 1   Mid-Quality      1654
# 2  Poor-Quality        35

# %%
sql_query = """
-- INNER JOIN: Employee asigned to each Customer
SELECT c.CustomerId, e.EmployeeId, e.FirstName, e.LastName, e.Title
FROM Customer AS c
INNER JOIN Employee as e
ON c.SupportRepId = e.EmployeeId;
"""

pd.read_sql(sql_query, con)
# Out:
#     CustomerId  EmployeeId FirstName LastName                Title
# 0            1           3      Jane  Peacock  Sales Support Agent
# 1            3           3      Jane  Peacock  Sales Support Agent
# 2           12           3      Jane  Peacock  Sales Support Agent
# 3           15           3      Jane  Peacock  Sales Support Agent
# 4           18           3      Jane  Peacock  Sales Support Agent
# 5           19           3      Jane  Peacock  Sales Support Agent
# 6           24           3      Jane  Peacock  Sales Support Agent
# 7           29           3      Jane  Peacock  Sales Support Agent
# 8           30           3      Jane  Peacock  Sales Support Agent
# 9           33           3      Jane  Peacock  Sales Support Agent
# 10          37           3      Jane  Peacock  Sales Support Agent
# 11          38           3      Jane  Peacock  Sales Support Agent
# 12          42           3      Jane  Peacock  Sales Support Agent
# 13          43           3      Jane  Peacock  Sales Support Agent
# 14          44           3      Jane  Peacock  Sales Support Agent
# 15          45           3      Jane  Peacock  Sales Support Agent
# 16          46           3      Jane  Peacock  Sales Support Agent
# 17          52           3      Jane  Peacock  Sales Support Agent
# 18          53           3      Jane  Peacock  Sales Support Agent
# 19          58           3      Jane  Peacock  Sales Support Agent
# 20          59           3      Jane  Peacock  Sales Support Agent
# 21           4           4  Margaret     Park  Sales Support Agent
# 22           5           4  Margaret     Park  Sales Support Agent
# 23           8           4  Margaret     Park  Sales Support Agent
# 24           9           4  Margaret     Park  Sales Support Agent
# 25          10           4  Margaret     Park  Sales Support Agent
# 26          13           4  Margaret     Park  Sales Support Agent
# 27          16           4  Margaret     Park  Sales Support Agent
# 28          20           4  Margaret     Park  Sales Support Agent
# 29          22           4  Margaret     Park  Sales Support Agent
# 30          23           4  Margaret     Park  Sales Support Agent
# 31          26           4  Margaret     Park  Sales Support Agent
# 32          27           4  Margaret     Park  Sales Support Agent
# 33          32           4  Margaret     Park  Sales Support Agent
# 34          34           4  Margaret     Park  Sales Support Agent
# 35          35           4  Margaret     Park  Sales Support Agent
# 36          39           4  Margaret     Park  Sales Support Agent
# 37          40           4  Margaret     Park  Sales Support Agent
# 38          49           4  Margaret     Park  Sales Support Agent
# 39          55           4  Margaret     Park  Sales Support Agent
# 40          56           4  Margaret     Park  Sales Support Agent
# 41           2           5     Steve  Johnson  Sales Support Agent
# 42           6           5     Steve  Johnson  Sales Support Agent
# 43           7           5     Steve  Johnson  Sales Support Agent
# 44          11           5     Steve  Johnson  Sales Support Agent
# 45          14           5     Steve  Johnson  Sales Support Agent
# 46          17           5     Steve  Johnson  Sales Support Agent
# 47          21           5     Steve  Johnson  Sales Support Agent
# 48          25           5     Steve  Johnson  Sales Support Agent
# 49          28           5     Steve  Johnson  Sales Support Agent
# 50          31           5     Steve  Johnson  Sales Support Agent
# 51          36           5     Steve  Johnson  Sales Support Agent
# 52          41           5     Steve  Johnson  Sales Support Agent
# 53          47           5     Steve  Johnson  Sales Support Agent
# 54          48           5     Steve  Johnson  Sales Support Agent
# 55          50           5     Steve  Johnson  Sales Support Agent
# 56          51           5     Steve  Johnson  Sales Support Agent
# 57          54           5     Steve  Johnson  Sales Support Agent
# 58          57           5     Steve  Johnson  Sales Support Agent
